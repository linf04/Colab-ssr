# %% [markdown]
# <a href="https://colab.research.google.com/github/linf04/Colab-ssr/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2.安装tailscale

# %%
# !curl -fsSL https://tailscale.com/install.sh | sh
# Out:
# Installing Tailscale for ubuntu jammy, using method apt
# + mkdir -p --mode=0755 /usr/share/keyrings
# + + curl -fsSL https://pkgs.tailscale.com/stable/ubuntu/jammy.noarmor.gpg
# tee /usr/share/keyrings/tailscale-archive-keyring.gpg
# + chmod 0644 /usr/share/keyrings/tailscale-archive-keyring.gpg
# + + curltee /etc/apt/sources.list.d/tailscale.list -fsSL
#  https://pkgs.tailscale.com/stable/ubuntu/jammy.tailscale-keyring.list
# # Tailscale packages for ubuntu jammy
# deb [signed-by=/usr/share/keyrings/tailscale-archive-keyring.gpg] https://pkgs.tailscale.com/stable/ubuntu jammy main
# + chmod 0644 /etc/apt/sources.list.d/tailscale.list
# + apt-get update
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# ...

# %% [markdown]
# #3.启动tailscale
# 请点击最后的链接，为tailscale登录授权

# %%
# !wget https://pan.432511.xyz/f/Gdu5/tail.sh && chmod +x  ./tail.sh && ./tail.sh && tailscale up
# Out:
# --2026-01-19 07:20:41--  https://pan.432511.xyz/f/Gdu5/tail.sh
# Resolving pan.432511.xyz (pan.432511.xyz)... 43.251.100.124
# Connecting to pan.432511.xyz (pan.432511.xyz)|43.251.100.124|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://pan.432511.xyz/api/v4/file/content/0x5hN/0/tail.sh?sign=MZREW9RRCR7imgwKbmCS4Ed-0SS5E9CwNApn4pfAZzo%3D%3A1768810842 [following]
# --2026-01-19 07:20:42--  https://pan.432511.xyz/api/v4/file/content/0x5hN/0/tail.sh?sign=MZREW9RRCR7imgwKbmCS4Ed-0SS5E9CwNApn4pfAZzo%3D%3A1768810842
# Reusing existing connection to pan.432511.xyz:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2505 (2.4K) [application/x-sh]
# Saving to: ‘tail.sh’
#
# tail.sh             100%[===================>]   2.45K  --.-KB/s    in 0s
#
# 2026-01-19 07:20:42 (684 MB/s) - ‘tail.sh’ saved [2505/2505]
#
# 正在启动 Tailscale 用户空间模式（SOCKS5 端口：1055）...
# Tailscale 用户空间模式启动成功！
#   - SOCKS5 代理地址：localhost:1055
#   - 进程 PID：1145
# ...

# %% [markdown]
# #4.安装ssr
# 请选择数字手动配置，最后会启动失败，因为pyhon2没安装

# %%
# !wget https://pan.432511.xyz/f/qPcB/ssr.sh && chmod +x ./ssr.sh && sudo ./ssr.sh
# Out:
# --2026-01-19 07:22:00--  https://pan.432511.xyz/f/qPcB/ssr.sh
# Resolving pan.432511.xyz (pan.432511.xyz)... 43.251.100.124
# Connecting to pan.432511.xyz (pan.432511.xyz)|43.251.100.124|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://pan.432511.xyz/api/v4/file/content/NWXt7/0/ssr.sh?sign=HizRvCsAEuc5JuQT4Jwf5yJv-fl6psqhtIeUQOrDpKk%3D%3A1768810920 [following]
# --2026-01-19 07:22:00--  https://pan.432511.xyz/api/v4/file/content/NWXt7/0/ssr.sh?sign=HizRvCsAEuc5JuQT4Jwf5yJv-fl6psqhtIeUQOrDpKk%3D%3A1768810920
# Reusing existing connection to pan.432511.xyz:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 61181 (60K) [application/x-sh]
# Saving to: ‘ssr.sh’
#
# ssr.sh              100%[===================>]  59.75K   383KB/s    in 0.2s
#
# 2026-01-19 07:22:01 (383 KB/s) - ‘ssr.sh’ saved [61181/61181]
#
#   ShadowsocksR 一键管理脚本 [v2.0.38]
#   ---- Toyo | doub.io/ss-jc42 ----
#
#   1. 安装 ShadowsocksR
#   2. 更新 ShadowsocksR
# ...

# %% [markdown]
# #5.安装Python2启动ssr

# %%
# !apt install -y python2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python2-minimal
#   python2.7 python2.7-minimal
# Suggested packages:
#   python2-doc python-tk python2.7-doc binfmt-support
# The following NEW packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python2
#   python2-minimal python2.7 python2.7-minimal
# 0 upgraded, 7 newly installed, 0 to remove and 51 not upgraded.
# Need to get 4,012 kB of archives.
# After this operation, 16.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpython2.7-minimal amd64 2.7.18-13ubuntu1.5 [347 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python2.7-minimal amd64 2.7.18-13ubuntu1.5 [1,400 kB]
# ...

# %%
# !sudo ln -s /usr/bin/python2.7 /usr/bin/python

# %%
# !printf "10\n" | sudo ./ssr.sh
# Out:
#   ShadowsocksR 一键管理脚本 [v2.0.38]
#   ---- Toyo | doub.io/ss-jc42 ----
#
#   1. 安装 ShadowsocksR
#   2. 更新 ShadowsocksR
#   3. 卸载 ShadowsocksR
#   4. 安装 libsodium(chacha20)
# ————————————
#   5. 查看 账号信息
#   6. 显示 连接信息
#   7. 设置 用户配置
#   8. 手动 修改配置
#   9. 切换 端口模式
# ————————————
#  10. 启动 ShadowsocksR
#  11. 停止 ShadowsocksR
#  12. 重启 ShadowsocksR
#  13. 查看 ShadowsocksR 日志
# ————————————
#  14. 其他功能
#  15. 升级脚本
#
#  当前状态: 已安装 但 未启动
#  当前模式: 单端口
#
# [信息] ShadowsocksR 启动成功 !
# ...
#
#  ShadowsocksR账号 配置信息：
#
#  I  P	    : 34.125.74.210
#  端口	    : 23333
#  密码	    : Key123!@#
#  加密	    : aes-256-cfb
#  协议	    : origin
#  混淆	    : plain
#  设备数限制 : 0(无限)
#  单线程限速 : 0 KB/S
#  端口总限速 : 0 KB/S
#  SS    链接 : ss://YWVzLTI1Ni1jZmI6S2V5MTIzIUAjQDM0LjEyNS43NC4yMTA6MjMzMzM
#  SS  二维码 : http://doub.pw/qr/qr.php?text=ss://YWVzLTI1Ni1jZmI6S2V5MTIzIUAjQDM0LjEyNS43NC4yMTA6MjMzMzM
#  SSR   链接 : ssr://MzQuMTI1Ljc0LjIxMDoyMzMzMzpvcmlnaW46YWVzLTI1Ni1jZmI6cGxhaW46UzJWNU1USXpJVUFq
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# # 总结
# 虽然是P2P，但是延迟很高，不如CodeSpace
